# %%
import tensorflow as tf

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow_hub as hub
from tensorflow.keras import layers
from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image
from tensorflow.keras.optimizers import Adam

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D

# %%
import logging
logger = tf.get_logger()
logger.setLevel(logging.ERROR)

# %%
train_dir = r"C:\Users\ROSHAAN\Desktop\TensorFlow\Data\train"
val_dir = r"C:\Users\ROSHAAN\Desktop\TensorFlow\Data\test"

# %%
batch_size = 100
IMG_SHAPE = 150

# %%
image_gen = ImageDataGenerator(rescale=1./255, horizontal_flip=True)

train_data_gen = image_gen.flow_from_directory(
                                                batch_size=batch_size,
                                                directory=train_dir,
                                                shuffle=True,
                                                target_size=(IMG_SHAPE,IMG_SHAPE)
                                                )
# Out:
# Found 3001 images belonging to 10 classes.

# %%
# This function will plot images in the form of a grid with 1 row and 5 columns where images are placed in each column.
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip( images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()


augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %%
image_gen = ImageDataGenerator(rescale=1./255, rotation_range=45)

train_data_gen = image_gen.flow_from_directory(batch_size=batch_size,
                                               directory=train_dir,
                                               shuffle=True,
                                               target_size=(IMG_SHAPE, IMG_SHAPE))
# Out:
# Found 3001 images belonging to 10 classes.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %%
image_gen = ImageDataGenerator(rescale=1./255, zoom_range=0.5)

train_data_gen = image_gen.flow_from_directory(
                                                batch_size=batch_size,
                                                directory=train_dir,
                                                shuffle=True,
                                                target_size=(IMG_SHAPE, IMG_SHAPE)
                                                )
# Out:
# Found 3001 images belonging to 10 classes.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %%
image_gen_train = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=45,
                    width_shift_range=.15,
                    height_shift_range=.15,
                    horizontal_flip=True,
                    zoom_range=0.5
                    )


train_data_gen = image_gen_train.flow_from_directory(
                                                batch_size=batch_size,
                                                directory=train_dir,
                                                shuffle=True,
                                                target_size=(IMG_SHAPE,IMG_SHAPE),
                                                class_mode='sparse'
                                                )
# Out:
# Found 3001 images belonging to 10 classes.

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %%
image_gen_val = ImageDataGenerator(rescale=1./255)

val_data_gen = image_gen_val.flow_from_directory(batch_size=batch_size,
                                                 directory=val_dir,
                                                 target_size=(IMG_SHAPE, IMG_SHAPE),
                                                 class_mode='sparse')
# Out:
# Found 500 images belonging to 10 classes.

# %%
model = Sequential()

model.add(Conv2D(16, 3, padding='same', activation='relu', input_shape=(IMG_SHAPE,IMG_SHAPE, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, 3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, 3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))

model.add(Dropout(0.2))
model.add(Dense(10,activation="softmax"))

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs = 80

history = model.fit_generator(
    train_data_gen,
    steps_per_epoch=int(np.ceil(train_data_gen.n / float(batch_size))),
    epochs=epochs,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(val_data_gen.n / float(batch_size)))
)
# Out:
# C:\Users\ROSHAAN\AppData\Local\Temp\ipykernel_17488\2136410573.py:3: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   history = model.fit_generator(
# Epoch 1/80
# 31/31 [==============================] - 98s 3s/step - loss: 2.3289 - accuracy: 0.1446 - val_loss: 2.0739 - val_accuracy: 0.2540
# Epoch 2/80
# 31/31 [==============================] - 85s 3s/step - loss: 2.0609 - accuracy: 0.2463 - val_loss: 1.8684 - val_accuracy: 0.3360
# Epoch 3/80
# 31/31 [==============================] - 92s 3s/step - loss: 2.0023 - accuracy: 0.2832 - val_loss: 1.7796 - val_accuracy: 0.3640
# Epoch 4/80
# 31/31 [==============================] - 96s 3s/step - loss: 1.8634 - accuracy: 0.3379 - val_loss: 1.7245 - val_accuracy: 0.3560
# Epoch 5/80
# 31/31 [==============================] - 95s 3s/step - loss: 1.8210 - accuracy: 0.3496 - val_loss: 1.6064 - val_accuracy: 0.4200
# Epoch 6/80
# 31/31 [==============================] - 96s 3s/step - loss: 1.7508 - accuracy: 0.3769 - val_loss: 1.6653 - val_accuracy: 0.4000
# Epoch 7/80
# 31/31 [==============================] - 90s 3s/step - loss: 1.7310 - accuracy: 0.3892 - val_loss: 1.6025 - val_accuracy: 0.4320
# Epoch 8/80
# 31/31 [==============================] - 90s 3s/step - loss: 1.6640 - accuracy: 0.4105 - val_loss: 1.4651 - val_accuracy: 0.5300
# Epoch 9/80
# 31/31 [==============================] - 94s 3s/step - loss: 1.6183 - accuracy: 0.4289 - val_loss: 1.4562 - val_accuracy: 0.4980
# Epoch 10/80
# 31/31 [==============================] - 96s 3s/step - loss: 1.5590 - accuracy: 0.4479 - val_loss: 1.3585 - val_accuracy: 0.5260
# Epoch 11/80
# 31/31 [==============================] - 102s 3s/step - loss: 1.5338 - accuracy: 0.4512 - val_loss: 1.4086 - val_accuracy: 0.5140
# Epoch 12/80
# 31/31 [==============================] - 107s 3s/step - loss: 1.5162 - accuracy: 0.4652 - val_loss: 1.3151 - val_accuracy: 0.5640
# Epoch 13/80
# 31/31 [==============================] - 96s 3s/step - loss: 1.4089 - accuracy: 0.5048 - val_loss: 1.2021 - val_accuracy: 0.5900
# Epoch 14/80
# 31/31 [==============================] - 91s 3s/step - loss: 1.3743 - accuracy: 0.5212 - val_loss: 1.1756 - val_accuracy: 0.6420
# Epoch 15/80
# 31/31 [==============================] - 92s 3s/step - loss: 1.2822 - accuracy: 0.5535 - val_loss: 1.0180 - val_accuracy: 0.7000
# Epoch 16/80
# 31/31 [==============================] - 90s 3s/step - loss: 1.3613 - accuracy: 0.5322 - val_loss: 1.1479 - val_accuracy: 0.6040
# Epoch 17/80
# 31/31 [==============================] - 90s 3s/step - loss: 1.2250 - accuracy: 0.5778 - val_loss: 0.9672 - val_accuracy: 0.7120
# Epoch 18/80
# 31/31 [==============================] - 88s 3s/step - loss: 1.1619 - accuracy: 0.5931 - val_loss: 0.9323 - val_accuracy: 0.7140
# Epoch 19/80
# 31/31 [==============================] - 87s 3s/step - loss: 1.2081 - accuracy: 0.5758 - val_loss: 0.9538 - val_accuracy: 0.7140
# Epoch 20/80
# 31/31 [==============================] - 89s 3s/step - loss: 1.1692 - accuracy: 0.5941 - val_loss: 0.8113 - val_accuracy: 0.7200
# Epoch 21/80
# 31/31 [==============================] - 86s 3s/step - loss: 1.1548 - accuracy: 0.5968 - val_loss: 1.1622 - val_accuracy: 0.6360
# Epoch 22/80
# 31/31 [==============================] - 86s 3s/step - loss: 1.2899 - accuracy: 0.5551 - val_loss: 0.9457 - val_accuracy: 0.6980
# Epoch 23/80
# 31/31 [==============================] - 87s 3s/step - loss: 1.0770 - accuracy: 0.6285 - val_loss: 0.8436 - val_accuracy: 0.7100
# Epoch 24/80
# 31/31 [==============================] - 91s 3s/step - loss: 0.9925 - accuracy: 0.6561 - val_loss: 1.0103 - val_accuracy: 0.6520
# Epoch 25/80
# 31/31 [==============================] - 98s 3s/step - loss: 1.1567 - accuracy: 0.5945 - val_loss: 0.7706 - val_accuracy: 0.7720
# Epoch 26/80
# 31/31 [==============================] - 96s 3s/step - loss: 1.1489 - accuracy: 0.6045 - val_loss: 0.8070 - val_accuracy: 0.7620
# Epoch 27/80
# 31/31 [==============================] - 95s 3s/step - loss: 0.9743 - accuracy: 0.6578 - val_loss: 0.6641 - val_accuracy: 0.7920
# Epoch 28/80
# 31/31 [==============================] - 89s 3s/step - loss: 0.9538 - accuracy: 0.6651 - val_loss: 0.6867 - val_accuracy: 0.8080
# Epoch 29/80
# 31/31 [==============================] - 85s 3s/step - loss: 0.8280 - accuracy: 0.7118 - val_loss: 0.5839 - val_accuracy: 0.8360
# Epoch 30/80
# 31/31 [==============================] - 85s 3s/step - loss: 0.8169 - accuracy: 0.7208 - val_loss: 1.4772 - val_accuracy: 0.6040
# Epoch 31/80
# 31/31 [==============================] - 83s 3s/step - loss: 1.1882 - accuracy: 0.5935 - val_loss: 0.6915 - val_accuracy: 0.8000
# Epoch 32/80
# 31/31 [==============================] - 85s 3s/step - loss: 1.0746 - accuracy: 0.6371 - val_loss: 0.7121 - val_accuracy: 0.8080
# Epoch 33/80
# 31/31 [==============================] - 88s 3s/step - loss: 0.8652 - accuracy: 0.7158 - val_loss: 0.5562 - val_accuracy: 0.8340
# Epoch 34/80
# 31/31 [==============================] - 86s 3s/step - loss: 0.7607 - accuracy: 0.7344 - val_loss: 0.6693 - val_accuracy: 0.8060
# Epoch 35/80
# 31/31 [==============================] - 88s 3s/step - loss: 0.7395 - accuracy: 0.7454 - val_loss: 0.5375 - val_accuracy: 0.8580
# Epoch 36/80
# 31/31 [==============================] - 96s 3s/step - loss: 0.7183 - accuracy: 0.7554 - val_loss: 0.5592 - val_accuracy: 0.8480
# Epoch 37/80
# 31/31 [==============================] - 95s 3s/step - loss: 0.7139 - accuracy: 0.7611 - val_loss: 0.5044 - val_accuracy: 0.8540
# Epoch 38/80
# 31/31 [==============================] - 103s 3s/step - loss: 0.7075 - accuracy: 0.7554 - val_loss: 0.4639 - val_accuracy: 0.8760
# Epoch 39/80
# 31/31 [==============================] - 90s 3s/step - loss: 0.6607 - accuracy: 0.7714 - val_loss: 0.4501 - val_accuracy: 0.8740
# Epoch 40/80
# 31/31 [==============================] - 89s 3s/step - loss: 0.6218 - accuracy: 0.7727 - val_loss: 0.3504 - val_accuracy: 0.9200
# Epoch 41/80
# 31/31 [==============================] - 92s 3s/step - loss: 0.5571 - accuracy: 0.8191 - val_loss: 0.4419 - val_accuracy: 0.8900
# Epoch 42/80
# 31/31 [==============================] - 92s 3s/step - loss: 0.5850 - accuracy: 0.7944 - val_loss: 0.4488 - val_accuracy: 0.8760
# Epoch 43/80
# 31/31 [==============================] - 113s 4s/step - loss: 0.5815 - accuracy: 0.8054 - val_loss: 0.3973 - val_accuracy: 0.8900
# Epoch 44/80
# 31/31 [==============================] - 106s 3s/step - loss: 0.5399 - accuracy: 0.8061 - val_loss: 0.3752 - val_accuracy: 0.9000
# Epoch 45/80
# 31/31 [==============================] - 107s 3s/step - loss: 0.4887 - accuracy: 0.8317 - val_loss: 0.2948 - val_accuracy: 0.9240
# Epoch 46/80
# 31/31 [==============================] - 109s 4s/step - loss: 0.4793 - accuracy: 0.8311 - val_loss: 0.3512 - val_accuracy: 0.9040
# Epoch 47/80
# 31/31 [==============================] - 95s 3s/step - loss: 0.4660 - accuracy: 0.8471 - val_loss: 0.3033 - val_accuracy: 0.9220
# Epoch 48/80
# 31/31 [==============================] - 87s 3s/step - loss: 0.4596 - accuracy: 0.8344 - val_loss: 0.3063 - val_accuracy: 0.9220
# Epoch 49/80
# 31/31 [==============================] - 85s 3s/step - loss: 0.7287 - accuracy: 0.7564 - val_loss: 0.4056 - val_accuracy: 0.8860
# Epoch 50/80
# 31/31 [==============================] - 83s 3s/step - loss: 0.5219 - accuracy: 0.8217 - val_loss: 0.2991 - val_accuracy: 0.9140
# Epoch 51/80
# 31/31 [==============================] - 93s 3s/step - loss: 0.6648 - accuracy: 0.7717 - val_loss: 0.4345 - val_accuracy: 0.8840
# Epoch 52/80
# 31/31 [==============================] - 91s 3s/step - loss: 0.7068 - accuracy: 0.7521 - val_loss: 0.7102 - val_accuracy: 0.7760
# Epoch 53/80
# 31/31 [==============================] - 90s 3s/step - loss: 0.6673 - accuracy: 0.7654 - val_loss: 0.3836 - val_accuracy: 0.9020
# Epoch 54/80
# 31/31 [==============================] - 90s 3s/step - loss: 0.5191 - accuracy: 0.8261 - val_loss: 0.3500 - val_accuracy: 0.9140
# Epoch 55/80
# 31/31 [==============================] - 96s 3s/step - loss: 0.4631 - accuracy: 0.8467 - val_loss: 0.2994 - val_accuracy: 0.9380
# Epoch 56/80
# 31/31 [==============================] - 97s 3s/step - loss: 0.4100 - accuracy: 0.8627 - val_loss: 0.3463 - val_accuracy: 0.9180
# Epoch 57/80
# 31/31 [==============================] - 95s 3s/step - loss: 0.3738 - accuracy: 0.8697 - val_loss: 0.3176 - val_accuracy: 0.9300
# Epoch 58/80
# 31/31 [==============================] - 93s 3s/step - loss: 0.3854 - accuracy: 0.8630 - val_loss: 0.2880 - val_accuracy: 0.9200
# Epoch 59/80
# 31/31 [==============================] - 78s 2s/step - loss: 0.3575 - accuracy: 0.8680 - val_loss: 0.4194 - val_accuracy: 0.9160
# Epoch 60/80
# 31/31 [==============================] - 70s 2s/step - loss: 0.4896 - accuracy: 0.8287 - val_loss: 0.2927 - val_accuracy: 0.9280
# Epoch 61/80
# 31/31 [==============================] - 73s 2s/step - loss: 0.3897 - accuracy: 0.8634 - val_loss: 0.3005 - val_accuracy: 0.9440
# Epoch 62/80
# 31/31 [==============================] - 64s 2s/step - loss: 0.3961 - accuracy: 0.8667 - val_loss: 0.3053 - val_accuracy: 0.9380
# Epoch 63/80
# 31/31 [==============================] - 69s 2s/step - loss: 0.5032 - accuracy: 0.8327 - val_loss: 0.3132 - val_accuracy: 0.9140
# Epoch 64/80
# 31/31 [==============================] - 66s 2s/step - loss: 0.4836 - accuracy: 0.8437 - val_loss: 0.2939 - val_accuracy: 0.9280
# Epoch 65/80
# 31/31 [==============================] - 68s 2s/step - loss: 0.3919 - accuracy: 0.8627 - val_loss: 0.2666 - val_accuracy: 0.9380
# Epoch 66/80
# 31/31 [==============================] - 63s 2s/step - loss: 0.3400 - accuracy: 0.8790 - val_loss: 0.3123 - val_accuracy: 0.9320
# Epoch 67/80
# 31/31 [==============================] - 64s 2s/step - loss: 0.3140 - accuracy: 0.8954 - val_loss: 0.3075 - val_accuracy: 0.9360
# Epoch 68/80
# 31/31 [==============================] - 67s 2s/step - loss: 0.3048 - accuracy: 0.8937 - val_loss: 0.3385 - val_accuracy: 0.9380
# Epoch 69/80
# 31/31 [==============================] - 77s 2s/step - loss: 0.2983 - accuracy: 0.8904 - val_loss: 0.2915 - val_accuracy: 0.9480
# Epoch 70/80
# 31/31 [==============================] - 84s 3s/step - loss: 0.3519 - accuracy: 0.8770 - val_loss: 0.3635 - val_accuracy: 0.9380
# Epoch 71/80
# 31/31 [==============================] - 77s 2s/step - loss: 0.4296 - accuracy: 0.8530 - val_loss: 0.2633 - val_accuracy: 0.9420
# Epoch 72/80
# 31/31 [==============================] - 69s 2s/step - loss: 0.3039 - accuracy: 0.8957 - val_loss: 0.2973 - val_accuracy: 0.9420
# Epoch 73/80
# 31/31 [==============================] - 65s 2s/step - loss: 0.2932 - accuracy: 0.8990 - val_loss: 0.3260 - val_accuracy: 0.9200
# Epoch 74/80
# 31/31 [==============================] - 66s 2s/step - loss: 0.2934 - accuracy: 0.8967 - val_loss: 0.2677 - val_accuracy: 0.9480
# Epoch 75/80
# 31/31 [==============================] - 72s 2s/step - loss: 0.3263 - accuracy: 0.8904 - val_loss: 0.4137 - val_accuracy: 0.9100
# Epoch 76/80
# 31/31 [==============================] - 64s 2s/step - loss: 0.3379 - accuracy: 0.8820 - val_loss: 0.3232 - val_accuracy: 0.9360
# Epoch 77/80
# 31/31 [==============================] - 65s 2s/step - loss: 0.2915 - accuracy: 0.8980 - val_loss: 0.3316 - val_accuracy: 0.9280
# Epoch 78/80
# 31/31 [==============================] - 65s 2s/step - loss: 0.2698 - accuracy: 0.9060 - val_loss: 0.3201 - val_accuracy: 0.9380
# Epoch 79/80
# 31/31 [==============================] - 70s 2s/step - loss: 0.2559 - accuracy: 0.9127 - val_loss: 0.3150 - val_accuracy: 0.9420
# Epoch 80/80
# 31/31 [==============================] - 68s 2s/step - loss: 0.2457 - accuracy: 0.9147 - val_loss: 0.2943 - val_accuracy: 0.9500

# %%
model.save("Trained.h5")
